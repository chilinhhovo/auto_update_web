# %% [markdown]
# # Community full board scrapper
#
# All community boards have separate sites for their minutes
#
# > I watched Soma's youtube tutorial https://www.youtube.com/watch?v=QNKxzkNpsko

# %% [markdown]
# I chatted with Soma, and he said he imagined each community board to have one scrapper, and it's better to have a minimum viable product since it looks more impressive on your CV than attempting and learning something even if it fails.

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using either Playwrightfor this, *not* requests.

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.nyc.gov/site/bronxcb1/calendar/board-meeting-minutes.page), search for all community board meeting minutes from Community Board 1 Bronx

# %% [markdown]
# # Finding all minutes

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the webpage to scrape
url = "https://www.nyc.gov/site/bronxcb1/calendar/board-meeting-minutes.page"

# Fetch the HTML content of the page
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    html_content = response.text
    # Parse the HTML content with BeautifulSoup
    soup_doc = BeautifulSoup(html_content, "html.parser")
    # Find all divs with class "span6 about-description"
    divs = soup_doc.find_all("div", class_="span6 about-description")
    
    # Lists to store the extracted data
    dates = []
    urls = []

    # Process each div to extract dates and URLs
    for div in divs:
        # Extract all links within the div
        links = div.find_all("a", href=True)
        for link in links:
            # Append the full URL (combine with base URL if relative) and the corresponding text
            url = f"https://www.nyc.gov{link['href']}"  # Assuming the href is a relative path
            text = link.text.strip()
            urls.append(url)
            dates.append(text)
    
    # Create a DataFrame
    df = pd.DataFrame({
        "Date": dates,
        "URL": urls
    })

    # Save the DataFrame to a CSV file
    output_file = "Bronx_CB1.csv"
    df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")

else:
    print(f"Failed to fetch the webpage. Status code: {response.status_code}")
# Out:
# Data saved to Bronx_CB1.csv

# %%
import pandas as pd
df.head()
# Out:
#                         Date  \
# 0      June 20, 2024 Minutes
# 1       May 30, 2024 Minutes
# 2     April 30, 2024 Minutes
# 3     March 28, 2024 Minutes
# 4  February 29, 2024 Minutes
#
#                                                  URL
# 0  https://www.nyc.gov/assets/bronxcb1/pdf/minute...
# 1  https://www.nyc.gov/assets/bronxcb1/pdf/minute...
# 2  https://www.nyc.gov/assets/bronxcb1/pdf/minute...
# 3  https://www.nyc.gov/assets/bronxcb1/pdf/minute...
# 4  https://www.nyc.gov/assets/bronxcb1/pdf/minute...

# %% [markdown]
# # Export the df

# %% [markdown]
# I stole this code from the internet and fixed it up, link [here](https://www.geeksforgeeks.org/downloading-pdfs-with-python-using-requests-and-beautifulsoup/)

# %%
import os
import requests
import pandas as pd
import pdfplumber
# from doctr.io import DocumentFile
# from doctr.models import ocr_predictor
# from pdf2image import convert_from_path
# from google.cloud import vision
from PIL import Image
import pytesseract

# Initialize DocTR OCR Predictor
ocr_model = ocr_predictor(pretrained=True)

# Google Vision OCR Function
def extract_text_with_google_vision(pdf_path):
    client = vision.ImageAnnotatorClient()
    text = ""
    try:
        # Convert PDF pages to images and send to Google Vision API
        pages = convert_from_path(pdf_path)
        for page in pages:
            # Convert the image to bytes
            image_bytes = page.tobytes("raw", "RGB")
            image = vision.Image(content=image_bytes)
            response = client.text_detection(image=image)
            text += response.full_text_annotation.text + "\n"
    except Exception as e:
        print(f"Google Vision OCR failed: {e}")
        text = "Error extracting content"
    return text.strip()

# Tesseract OCR Function
def extract_text_with_tesseract(pdf_path):
    text = ""
    try:
        pages = convert_from_path(pdf_path)
        for page in pages:
            text += pytesseract.image_to_string(page) + "\n"
    except Exception as e:
        print(f"Tesseract OCR failed: {e}")
        text = "Error extracting content"
    return text.strip()

# Load the DataFrame
input_file = "Bronx_CB1.csv"
df = pd.read_csv(input_file)

# Folder to store downloaded PDFs
folder_name = "Bronx_CB1_PDFs"
os.makedirs(folder_name, exist_ok=True)

# Initialize a list to store content
content_list = []
failed_files = []

# Iterate over each row in the DataFrame
for index, row in df.iterrows():
    url = row['URL']
    date = row['Date']

    try:
        print(f"Processing: {date} ({url})")
        file_name = os.path.basename(url)
        file_path = os.path.join(folder_name, file_name)

        if not os.path.exists(file_path):
            response = requests.get(url)
            with open(file_path, 'wb') as pdf_file:
                pdf_file.write(response.content)
            print(f"Downloaded: {file_path}")

        pdf_text = ""
        # Step 1: Attempt to extract with pdfplumber
        try:
            with pdfplumber.open(file_path) as pdf:
                for page in pdf.pages:
                    pdf_text += page.extract_text() or ""
        except Exception as e:
            print(f"pdfplumber failed for {file_name}: {e}")

        # Step 2: Fallback to DocTR if pdfplumber fails
    #     if not pdf_text.strip():
    #         print(f"Using DocTR for OCR on {file_name}")
    #         try:
    #             pdf_doc = DocumentFile.from_pdf(file_path)
    #             ocr_result = ocr_model(pdf_doc)
    #             pdf_text = "\n".join(page["content"] for page in ocr_result.export()["pages"])
    #         except Exception as e:
    #             print(f"DocTR failed for {file_name}: {e}")

    #     # Step 3: Fallback to Tesseract OCR if DocTR fails
    #     if not pdf_text.strip():
    #         print(f"Using Tesseract OCR for {file_name}")
    #         pdf_text = extract_text_with_tesseract(file_path)

    #     # Step 4: Final fallback to Google Vision OCR if Tesseract fails
    #     if not pdf_text.strip():
    #         print(f"Using Google Vision OCR for {file_name}")
    #         pdf_text = extract_text_with_google_vision(file_path)

    #     # Log files that could not be processed
    #     if not pdf_text.strip():
    #         failed_files.append(file_name)
    #         pdf_text = "Manual review required"

    #     content_list.append(pdf_text.strip())

    # except Exception as e:
    #     print(f"Error processing {date}: {e}")
    #     content_list.append("Error extracting content")

# Add the content as a new column in the DataFrame
df['Content'] = content_list
df.to_csv("Bronx_CB1_with_content.csv", index=False)

# Save failed files for manual review
with open("failed_files.log", "w") as log_file:
    log_file.write("\n".join(Bronx_CB1_failed_files))

print("Processing complete. Check 'Bronx_CB1_with_content.csv' and 'failed_files.log'.")
# Out:
# /Users/chivo/.pyenv/versions/3.10.12/lib/python3.10/site-packages/doctr/models/utils/pytorch.py:59: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(archive_path, map_location="cpu")
# Processing: June 20, 2024 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/June-24-Official-Minutes-General-Board.pdf)
# Using DocTR for OCR on June-24-Official-Minutes-General-Board.pdf
# DocTR failed for June-24-Official-Minutes-General-Board.pdf: 'content'
# Using Tesseract OCR for June-24-Official-Minutes-General-Board.pdf
# Processing: May 30, 2024 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/May-24-Official-Minutes-General-Board.pdf)
# Using DocTR for OCR on May-24-Official-Minutes-General-Board.pdf
# DocTR failed for May-24-Official-Minutes-General-Board.pdf: 'content'
# Using Tesseract OCR for May-24-Official-Minutes-General-Board.pdf
# Processing: April 30, 2024 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/April-24-Official-Minutes-General-Board.pdf)
# Using DocTR for OCR on April-24-Official-Minutes-General-Board.pdf
# DocTR failed for April-24-Official-Minutes-General-Board.pdf: 'content'
# Using Tesseract OCR for April-24-Official-Minutes-General-Board.pdf
# Processing: March 28, 2024 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/March-24-Official-Minutes-General-Board-Meeting.pdf)
# Processing: February 29, 2024 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/February-24-Official-Minutes-General-Board.pdf)
# Using DocTR for OCR on February-24-Official-Minutes-General-Board.pdf
# DocTR failed for February-24-Official-Minutes-General-Board.pdf: 'content'
# Using Tesseract OCR for February-24-Official-Minutes-General-Board.pdf
# Processing: November 30, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/November-23-Minutes.pdf)
# Using DocTR for OCR on November-23-Minutes.pdf
# DocTR failed for November-23-Minutes.pdf: 'content'
# Using Tesseract OCR for November-23-Minutes.pdf
# Processing: October 26, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/October-23-Minutes.pdf)
# Using DocTR for OCR on October-23-Minutes.pdf
# DocTR failed for October-23-Minutes.pdf: 'content'
# Using Tesseract OCR for October-23-Minutes.pdf
# Processing: September 28, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/September-23-Minutes.pdf)
# Using DocTR for OCR on September-23-Minutes.pdf
# DocTR failed for September-23-Minutes.pdf: 'content'
# Using Tesseract OCR for September-23-Minutes.pdf
# Processing: May 25, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting5-25-23.pdf)
# Processing: April 27, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting4-27-23.pdf)
# Processing: March 30, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting3-30-23.pdf)
# Processing: February 23, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting2-23-23.pdf)
# Processing: January 26, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting1-26-23.pdf)
# Processing: January 19, 2023 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeetingSpecial1-19-23.pdf)
# Processing: December 15, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting12-15-22.pdf)
# Processing: November 17, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting11-17-22.pdf)
# Using DocTR for OCR on FullBoardMeeting11-17-22.pdf
# DocTR failed for FullBoardMeeting11-17-22.pdf: 'content'
# Using Tesseract OCR for FullBoardMeeting11-17-22.pdf
# Processing: October 27, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/Full-Board-Minutes-10-17-22.pdf)
# Using DocTR for OCR on Full-Board-Minutes-10-17-22.pdf
# DocTR failed for Full-Board-Minutes-10-17-22.pdf: 'content'
# Using Tesseract OCR for Full-Board-Minutes-10-17-22.pdf
# Processing: September 29, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoard9.29.22.pdf)
# Using DocTR for OCR on FullBoard9.29.22.pdf
# DocTR failed for FullBoard9.29.22.pdf: 'content'
# Using Tesseract OCR for FullBoard9.29.22.pdf
# Processing: April 28, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/Full-Board-Apr-2022-Minutes.pdf)
# Using DocTR for OCR on Full-Board-Apr-2022-Minutes.pdf
# DocTR failed for Full-Board-Apr-2022-Minutes.pdf: 'content'
# Using Tesseract OCR for Full-Board-Apr-2022-Minutes.pdf
# Processing: March 31, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/Full-Board-3-31-22.pdf)
# Using DocTR for OCR on Full-Board-3-31-22.pdf
# DocTR failed for Full-Board-3-31-22.pdf: 'content'
# Using Tesseract OCR for Full-Board-3-31-22.pdf
# Processing: January 27, 2022 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoard-1-27-22.pdf)
# Using DocTR for OCR on FullBoard-1-27-22.pdf
# DocTR failed for FullBoard-1-27-22.pdf: 'content'
# Using Tesseract OCR for FullBoard-1-27-22.pdf
# Processing: December 16, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting12-16-21.pdf)
# Processing: November 18, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeeting11-18-21.pdf)
# Processing: October 28, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-202110.pdf)
# Using DocTR for OCR on minutes-202110.pdf
# DocTR failed for minutes-202110.pdf: 'content'
# Using Tesseract OCR for minutes-202110.pdf
# Processing: September 30, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-202109.pdf)
# Using DocTR for OCR on minutes-202109.pdf
# DocTR failed for minutes-202109.pdf: 'content'
# Using Tesseract OCR for minutes-202109.pdf
# Processing: July 14, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-202107.pdf)
# Using DocTR for OCR on minutes-202107.pdf
# DocTR failed for minutes-202107.pdf: 'content'
# Using Tesseract OCR for minutes-202107.pdf
# Processing: June 24, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-202106.pdf)
# Using DocTR for OCR on minutes-202106.pdf
# DocTR failed for minutes-202106.pdf: 'content'
# Using Tesseract OCR for minutes-202106.pdf
# Processing: May 27, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMay2021.pdf)
# Processing: April 29, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardApr2021.pdf)
# Processing: February 25, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/fullboardmeeting2_25_21.pdf)
# Using DocTR for OCR on fullboardmeeting2_25_21.pdf
# DocTR failed for fullboardmeeting2_25_21.pdf: 'content'
# Using Tesseract OCR for fullboardmeeting2_25_21.pdf
# Processing: January 28, 2021 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/FullBoardMeeting1.28.21.pdf)
# Using DocTR for OCR on FullBoardMeeting1.28.21.pdf
# DocTR failed for FullBoardMeeting1.28.21.pdf: 'content'
# Using Tesseract OCR for FullBoardMeeting1.28.21.pdf
# Processing: December 17, 2020 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeetingMinutesJan2021.pdf)
# Using DocTR for OCR on FullBoardMeetingMinutesJan2021.pdf
# DocTR failed for FullBoardMeetingMinutesJan2021.pdf: 'content'
# Using Tesseract OCR for FullBoardMeetingMinutesJan2021.pdf
# Processing: November 19, 2020 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeetingMinutesNov2020.pdf)
# Using DocTR for OCR on FullBoardMeetingMinutesNov2020.pdf
# DocTR failed for FullBoardMeetingMinutesNov2020.pdf: 'content'
# Using Tesseract OCR for FullBoardMeetingMinutesNov2020.pdf
# Processing: October 29, 2020 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FullBoardMeetingMinutesOct2020.pdf)
# Using DocTR for OCR on FullBoardMeetingMinutesOct2020.pdf
# DocTR failed for FullBoardMeetingMinutesOct2020.pdf: 'content'
# Using Tesseract OCR for FullBoardMeetingMinutesOct2020.pdf
# Processing: October 30, 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/1FBOct2019.pdf)
# Using DocTR for OCR on 1FBOct2019.pdf
# DocTR failed for 1FBOct2019.pdf: 'content'
# Using Tesseract OCR for 1FBOct2019.pdf
# Processing: June 20, 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/Binder11343423424.pdf)
# Using DocTR for OCR on Binder11343423424.pdf
# DocTR failed for Binder11343423424.pdf: 'content'
# Using Tesseract OCR for Binder11343423424.pdf
# Processing: May 23, 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/board_minutes2019.pdf)
# Using DocTR for OCR on board_minutes2019.pdf
# DocTR failed for board_minutes2019.pdf: 'content'
# Using Tesseract OCR for board_minutes2019.pdf
# Processing: March 28, 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/fbminutes3_28_19.pdf)
# Using DocTR for OCR on fbminutes3_28_19.pdf
# DocTR failed for fbminutes3_28_19.pdf: 'content'
# Using Tesseract OCR for fbminutes3_28_19.pdf
# Processing: February 28, 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/fbfeb2019_minutes.pdf)
# Using DocTR for OCR on fbfeb2019_minutes.pdf
# DocTR failed for fbfeb2019_minutes.pdf: 'content'
# Using Tesseract OCR for fbfeb2019_minutes.pdf
# Processing: January 31 2019 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/Binder1.pdf)
# Using DocTR for OCR on Binder1.pdf
# DocTR failed for Binder1.pdf: 'content'
# Using Tesseract OCR for Binder1.pdf
# Processing: June 27, 2018 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/FBJune2018_full.pdf)
# Using DocTR for OCR on FBJune2018_full.pdf
# DocTR failed for FBJune2018_full.pdf: 'content'
# Using Tesseract OCR for FBJune2018_full.pdf
# Processing: October 26, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-oct2017.pdf)
# Using DocTR for OCR on minutes-oct2017.pdf
# DocTR failed for minutes-oct2017.pdf: 'content'
# Using Tesseract OCR for minutes-oct2017.pdf
# Processing: September 28, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-sep2017.pdf)
# Processing: June 29, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jun2017.pdf)
# Processing: April 27, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-apr2017.pdf)
# Processing: March 30, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-mar2017.pdf)
# Processing: Febuary 23, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-feb2017.pdf)
# Using DocTR for OCR on minutes-feb2017.pdf
# DocTR failed for minutes-feb2017.pdf: 'content'
# Using Tesseract OCR for minutes-feb2017.pdf
# Processing: January 26, 2017 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jan2017.pdf)
# Using DocTR for OCR on minutes-jan2017.pdf
# DocTR failed for minutes-jan2017.pdf: 'content'
# Using Tesseract OCR for minutes-jan2017.pdf
# Processing: February 25, 2016 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-feb2016.pdf)
# Processing: January 28, 2016 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jan2016.pdf)
# Processing: December 17, 2015 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-dec2015.pdf)
# Processing: October 29, 2015 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-oct2015.pdf)
# Processing: June 26, 2014 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jun2014.pdf)
# Processing: May 29, 2014 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-may2014.pdf)
# Processing: February 26, 2014 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-feb2014.pdf)
# Processing: January 30, 2014 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jan2014.pdf)
# Processing: December 19, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-dec2013.pdf)
# Processing: November 21, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-nov2013.pdf)
# Processing: May 30, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-may2013.pdf)
# Processing: April 25, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-apr2013.pdf)
# Processing: February 28, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-feb2013.pdf)
# Processing: January 31, 2013 Minutes (https://www.nyc.gov/assets/bronxcb1/pdf/minutes/minutes-jan2013.pdf)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 119
#     117 # Save failed files for manual review
#     118 with open("failed_files.log", "w") as log_file:
# --> 119     log_file.write("\n".join(Bronx_CB1_failed_files))
#     121 print("Processing complete. Check 'Bronx_CB1_with_content.csv' and 'failed_files.log'.")
#
# NameError: name 'Bronx_CB1_failed_files' is not defined

# %% [markdown]
# # Print PDF

# %% [markdown]
# I used this link from Soma's website [here](https://jonathansoma.com/everything/pdfs/ocr-tools/)
