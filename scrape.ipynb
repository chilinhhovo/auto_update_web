# %% [markdown]
# # Texas Cosmetologist Violations
#
# Texas has a system for [searching for license violations](https://www.tdlr.texas.gov/cimsfo/fosearch.asp). You're going to search for cosmetologists!
#
# > You can use the classwork notebook and also [my Everything scraping reference](https://jonathansoma.com/everything/scraping)
#
# I shouldn't have to say this, but **do not use ChatGPT for this assignment.**

# %% [markdown]
# ## Setup: Import what you'll need to scrape the page
#
# We'll be using either Playwrightfor this, *not* requests.

# %%
from playwright.async_api import async_playwright
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=True)
page = await browser.new_page()
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")
from bs4 import BeautifulSoup

# %% [markdown]
# ## Starting your search
#
# Starting from [here](https://www.tdlr.texas.gov/cimsfo/fosearch.asp), search for cosmetologist violations for people with the last name **Nguyen**.

# %%
#I have been getting time error despite putting the correct surname in for at least 30 times!!! PLease help 
from playwright.async_api import async_playwright
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless=False)
page = await browser.new_page()
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")
from bs4 import BeautifulSoup
await page.get_by_label("Search by License Program Type").select_option('Cosmetologist')
await page.fill("input[id='pht_lnm']", "Nguyen")
await page.get_by_role("button", name="Search").click()
html = await page.content()
from bs4 import BeautifulSoup
soup_doc = BeautifulSoup(html, "html.parser")
table = soup_doc.find("div", class_="main-content")
if table:
    print("Results Found:")
    print(table.prettify())
else:
    print("No results found.")
print(table)

# %%
# #And then I got Server Error

# 404 - File or directory not found.
# The resource you are looking for might have been removed, had its name changed, or is temporarily unavailable.

# %%
page = await browser.new_page()
await page.goto("https://www.tdlr.texas.gov/cimsfo/fosearch.asp")
await page.get_by_label("Search by Last Name").fill('Nguyen')
await page.locator("input[name=\"B1\"]").click()

# %%
import io 
import pandas as pd
html = await page.content()
tables = pd.read_html(io.StringIO(html))
print(tables[0])
# Out:
#                                     Name and Location  \
# 0   NGUYEN, ELLIE UYEN City: HUMBLE  County: HARRI...
# 1   NGUYEN, PHUC City: HOUSTON  County: HARRIS  Zi...
# 2   NGUYEN, TRONG City: FORT WORTH  County: TARRAN...
# 3   NGUYEN, SA City: AUSTIN  County: TRAVIS  Zip C...
# 4   NGUYEN, LYNH City: RICHARDSON  County: DALLAS ...
# ..                                                ...
# 78  NGUYEN, KELLY PHUONG N  City: GARDEN GROVE  Co...
# 79  NGUYEN, QUOC BAO City: ARLINGTON  County: TARR...
# 80  NGUYEN, DANIEL THAO City: PLANO  County: COLLI...
# 81  NGUYEN, THANH THU City: EL PASO  County: EL PA...
# 82  NGUYEN, CINDY City: TEMPLE  County: BELL  Zip ...
#
#                                                 Order  \
# 0   Date: 10/30/2024 Respondents Ellie Uyen Nguyen...
# 1   Date: 10/9/2024 Respondent is assessed an admi...
# 2   Date: 9/18/2024 Respondents Hanh Ngo, Linh Ngo...
# 3   Date: 8/26/2024 Respondent is assessed an admi...
# 4   Date: 8/8/2024 Respondent is assessed an admin...
# ..                                                ...
# 78  Date: 9/29/2022 Respondent is assessed an admi...
# 79  Date: 9/19/2022 Respondent is assessed an admi...
# 80  Date: 9/19/2022 Respondent is assessed an admi...
# 81  Date: 9/8/2022 Respondent is assessed an admin...
# 82  Date: 9/8/2022 Respondent is assessed an admin...
#
#                                       Basis for Order
# 0   Respondents failed to clean, disinfect, and st...
# 1   Respondent failed to follow whirlpool foot spa...
# 2   Respondents failed to follow whirlpool foot sp...
# 3   Respondent failed to follow whirlpool foot spa...
# 4   Respondent failed to follow whirlpool foot spa...
# ..                                                ...
# 78  Respondent failed to keep a record of the date...
# 79  Respondent failed to follow whirlpool foot spa...
# 80  Respondent failed to clean and sanitize whirlp...
# 81  Respondent failed to clean and sanitize whirlp...
# 82  Respondent failed to utilize clean and disinfe...
#
# [83 rows x 3 columns]

# %% [markdown]
# ## Scraping
#
# Once you are on the results page, do this. **I step you through things bit by bit, so it's going to be a little different than we did in class.** Also, no `pd.read_html` allowed because this isn't reaaallly tabular data (or there's just too much to clean up).
#
# Once you've loaded the page: **what selector are you going to do use to find the data?** In class we used things like `.article` or `.head-list`.
#
# > You honestly can do this all with Playwright, no BeautifulSoup involved! But we didn't cover that in class so you should stick to this method:
# >
# > ```python
# > html = await page.content()
# > doc = BeautifulSoup(html)
# > ```

# %%
html = await page.content()
doc = BeautifulSoup(html)

# %% [markdown]
# ### Grab the rows, loop through each result and print the entire row
#
# It's probably too many rows to do all at once: once you have a list, use `[:10]` to only show the first ten! For example, if you saved the table rows into `results` you might do something like this:
#
# ```python
# for result in results[:10]:
#     print("------")
#     print(result)
# ```
#
# Although you'd want to print out the text from the row (I give example output below).

# %%
results = tables[0].values.tolist()
for result in results[:10]:
    print("------")
    print(result)
# Out:
# ------
# ['NGUYEN, ELLIE UYEN City: HUMBLE  County: HARRIS  Zip Code: 77346  License #: 798636 Complaint # COS20240003068', 'Date: 10/30/2024 Respondents Ellie Uyen Nguyen and Bao Q. Truong are assessed an administrative penalty in the amount of $3,750.', "Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect all wax pots; Respondents failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondents failed to dispose of single use items after each use."]
# ------
# ['NGUYEN, PHUC City: HOUSTON  County: HARRIS  Zip Code: 77083  License #: 807327 Complaint # COS20230005653', 'Date: 10/9/2024 Respondent is assessed an administrative penalty in the amount of $3,000.', 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.']
# ------
# ['NGUYEN, TRONG City: FORT WORTH  County: TARRANT  Zip Code: 76177  License #: 808004 Complaint # COS20240011518', 'Date: 9/18/2024 Respondents Hanh Ngo, Linh Ngo, Trinh Ngo and Trong Nguyen are assessed an administrative penalty in the amount of $2,500.', 'Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect shampoo bowls prior to use for each client; Respondents failed to properly disinfect implements at the end of each day.']
# ------
# ['NGUYEN, SA City: AUSTIN  County: TRAVIS  Zip Code: 78729  License #: 799667 Complaint # COS20240008640', 'Date: 8/26/2024 Respondent is assessed an administrative penalty in the amount of $2,000.', 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and disinfect all wax pots.']
# ------
# ['NGUYEN, LYNH City: RICHARDSON  County: DALLAS  Zip Code: 75081  License #: 811783 Complaint # COS20230004635', 'Date: 8/8/2024 Respondent is assessed an administrative penalty in the amount of $1,500.', 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.']
# ------
# ['NGUYEN, LISA City: PORT LAVACA  County: Calhoun  Zip Code: 77979  License #: 727222 Complaint # COS20230010686', 'Date: 7/24/2024 Respondent is assessed an administrative penalty in the amount of $2,250.', "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."]
# ------
# ['NGUYEN, CHAU MINH City: LAREDO  County: Webb  Zip Code: 78040  License #: 721939 Complaint # COS20220007736', 'Date: 7/17/2024 Respondent is assessed an administrative penalty in the amount of $1,000.', 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.']
# ------
# ['NGUYEN, KEVIN C  City: KYLE  County: HAYS  Zip Code: 78640  License #: 834106 Complaint # COS20230020006', 'Date: 6/25/2024 Respondent is assessed an administrative penalty in the amount of $5,000.', 'Respondent failed to clean and disinfect all wax pots; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations.']
# ------
# ['NGUYEN, THANH D  City: SAN ANTONIO  County: BEXAR  Zip Code: 78227  License #: 827407 Complaint # COS20240000594', 'Date: 6/25/2024 Respondent is assessed an administrative penalty in the amount of $3,500.', "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 6 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use."]
# ------
# ['NGUYEN, TAM THI City: KILLEEN  County: BELL  Zip Code: 76542  License #: 826185 Complaint # COS20240008070', 'Date: 6/25/2024 Respondent is assessed an administrative penalty in the amount of $3,750.', "Respondent failed to utilize clean and disinfected implements; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."]

# %% [markdown]
# The result should look something like this:
#
# ```
# Name and Location Order Basis for Order
# NGUYEN, THANH
# City: FRISCO
# County: COLLIN
# Zip Code: 75034
#
#
# License #: 790672
#
# Complaint # COS20210004784 Date: 11/16/2021
#
# Respondent is assessed an administrative penalty in the amount of $1,875. Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# NGUYEN, LONG D
# City: SAN SABA
# County: SAN SABA
# Zip Code: 76877
# ```

# %% [markdown]
# ### Loop through each result and print each person's name
#
# You'll probably get an error because the first one doesn't have a name. How do you make that not happen?! If you want to ignore an error, you use code like this:
#
# ```python
# try:
#    # try to do something
# except:
#    print("It didn't work')
# ```
#
# It should help you out. If you don't want to print anything when there's an error, you can type `pass` instead of the `print` statement.
#
# **Why doesn't the first one have a name?**
#
# Output should look like this:
#
# ```
# Doesn't have a name
# NGUYEN, THANH
# NGUYEN, LONG D
# NGUYEN, LUCIE HUONG
# NGUYEN, CHINH
# NGUYEN, JIMMY
# ```
#
# * *Tip: The name has a class you can use. The class name is reused in a lot of places, but because it's the first one you don't have to worry about that!*
# * *Tip: Instead of searching across the entire page – like `doc.select_one` – you should be doing your searching just inside of each **row** (I used this technique in the beginning of class with BeautifulSoup when we were scraping the books page)*

# %%
from bs4 import BeautifulSoup
html = await page.content()

soup_doc = BeautifulSoup(html, "html.parser")

rows = soup_doc.select("tr")

for row in rows[:10]:
    try:
        name = row.select_one("span.results_text")
        if name: 
            print(name.text.strip())
        else:
            print("No name found")
    except:
        print("Error:", e)
# Out:
# No name found
# NGUYEN, ELLIE UYEN
# NGUYEN, PHUC
# NGUYEN, TRONG
# NGUYEN, SA
# NGUYEN, LYNH
# NGUYEN, LISA
# NGUYEN, CHAU MINH
# NGUYEN, KEVIN C
# NGUYEN, THANH D

# %%
# results = soup_doc.find_all("span", class_="results_text")
# results

# %% [markdown]
# ## Loop through each result, printing each violation description ("Basis for order")
#
# Your results should look something like:
#
# ```
# Doesn't have a violation
# Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.
# ...
# ```
#
# > - *Tip: You'll get an error even if you're ALMOST right - which row is causing the problem?*
# > - *Tip: Or I guess you could just skip the one with the problem using try/except...*

# %%
for row in rows[:10]:
    try:
        complaint_td = row.find_all("td")[-1]
        if complaint_td: 
            complaint = complaint_td.text.strip()
            print(complaint)
        else:
            print("Doesn't have a complaint")
    except:
        print("Error: CHECKKK!!!")
# Out:
# Error: CHECKKK!!!
# Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect all wax pots; Respondents failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondents failed to dispose of single use items after each use.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.
# Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect shampoo bowls prior to use for each client; Respondents failed to properly disinfect implements at the end of each day.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and disinfect all wax pots.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions.
# Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.
# Respondent failed to clean and disinfect all wax pots; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations.
# Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 6 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.

# %% [markdown]
# ## Loop through each result, printing the complaint number
#
# Output should look similar to this:
#
# ```
# Doesn't have a complaint number
# COS20210004784
# COS20210009745
# COS20210011484
# ...
# ```
#
# - *Tip: Think about the order of the elements. Can you count from the opposite direction than you normally do?*

# %%
for row in rows[:10]:
    try:
        complaint_label = row.select_one("span.default_text:contains('Complaint #')")
        if complaint_label:
            complaint_number = complaint_label.find_next_sibling("span", class_="results_text")
            if complaint_number:
                print(complaint_number.text.strip())
            else:
                print("no complaint")
    except:
        print("Error: CHECKKK!!!")
# Out:
# COS20240003068
# COS20230005653
# COS20240011518
# COS20240008640
# COS20230004635
# COS20230010686
# COS20220007736
# COS20230020006
# COS20240000594

# %% [markdown]
# ## Saving the results
#
# ### Loop through each result to create a list of dictionaries
#
# Each dictionary must contain
#
# - Person's name
# - Violation description
# - Violation number
# - License Numbers
# - Zip Code
# - County
# - City
#
# Create a new dictionary for each result (except the header).
#
# Based on what you print out, the output might look something like:
#
# ```
# This row is broken: Name and Location Order Basis for Order
# {'name': 'NGUYEN, THANH', 'city': 'FRISCO', 'county': 'COLLIN', 'zip_code': '75034', 'complaint_no': 'COS20210004784', 'license_numbers': '790672', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 2 violations; Respondent operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, LONG D', 'city': 'SAN SABA', 'county': 'SAN SABA', 'zip_code': '76877', 'complaint_no': 'COS20210009745', 'license_numbers': '760420, 1620583', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# ```
#
# > _**Tip:** Depending on how you do this, you might want to figure out how to search for "next siblings" or "following siblings"_

# %%
results = []
for row in rows[1:]: #Skipping header 
    try: 
        # name_span = row.select_one("span.results_text")
        # name = name_span.text.strip() if name_span else "No name"
        
        # city_span = row.select("span.results_text")[1] 
        # city = city_span.text.strip() if city_span else "No city"
        
        # county_span = row.select("span.results_text")[3] 
        # county = county_span.text.strip() if county_span else "No county"

        # zip_code_span = row.select("span.results_text")[5]
        # zip_code = zip_code_span.text.strip() if zip_code_span else "No zip code"

        # license_span = row.select("span.results_text")[7] 
        # license_numbers = license_span.text.strip() if license_span else "No license numbers"

        # complaint_no_span = row.select("span.results_text")[9] 
        # complaint_no = complaint_no_span.text.strip() if complaint_no_span else "No complaint number"

        # complaint_td = row.find_all("td")[-1] 
        # complaint = complaint_td.text.strip() if complaint_td else "No complaint description"

        name_span = row.select_one("span.results_text")
        name = name_span.text.strip() if name_span else "No name"

        spans = row.select("span.results_text")
        city = spans[1].text.strip() if len(spans) > 1 else "No city"
        county = spans[3].text.strip() if len(spans) > 3 else "No county"
        zip_code = spans[5].text.strip() if len(spans) > 5 else "No zip code"
        license_numbers = spans[7].text.strip() if len(spans) > 7 else "No license numbers"
        complaint_no = spans[9].text.strip() if len(spans) > 9 else "No complaint number"
        complaint_td = row.find_all("td")[-1]  
        complaint = complaint_td.text.strip() if complaint_td else "No complaint description"
        
        result = {
            "name": name,
            "city": city,
            "county": county,
            "zip_code": zip_code,
            "license_numbers": license_numbers,
            "complaint_no": complaint_no,
            "complaint": complaint,
        }
        results.append(result) 
    except:
        print(f"This row is broken: {row.text.strip()}")
        print("Error: CHECKKK!!!")

for result in results:
    print(result)
# Out:
# {'name': 'NGUYEN, ELLIE UYEN', 'city': 'HUMBLE', 'county': '77346', 'zip_code': 'COS20240003068', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect all wax pots; Respondents failed to clean diamond, carbide, natural and metal bits after each use with a brush or ultrasonic cleaner, or by immersing in acetone; Respondents failed to dispose of single use items after each use."}
# {'name': 'NGUYEN, PHUC', 'city': 'HOUSTON', 'county': '77083', 'zip_code': 'COS20230005653', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron.'}
# {'name': 'NGUYEN, TRONG', 'city': 'FORT WORTH', 'county': '76177', 'zip_code': 'COS20240011518', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean and disinfect shampoo bowls prior to use for each client; Respondents failed to properly disinfect implements at the end of each day.'}
# {'name': 'NGUYEN, SA', 'city': 'AUSTIN', 'county': '78729', 'zip_code': 'COS20240008640', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and disinfect all wax pots.'}
# {'name': 'NGUYEN, LYNH', 'city': 'RICHARDSON', 'county': '75081', 'zip_code': 'COS20230004635', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}
# {'name': 'NGUYEN, LISA', 'city': 'PORT LAVACA', 'county': '77979', 'zip_code': 'COS20230010686', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, CHAU MINH', 'city': 'LAREDO', 'county': '78040', 'zip_code': 'COS20220007736', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}
# {'name': 'NGUYEN, KEVIN C', 'city': 'KYLE', 'county': '78640', 'zip_code': 'COS20230020006', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations.'}
# {'name': 'NGUYEN, THANH D', 'city': 'SAN ANTONIO', 'county': '78227', 'zip_code': 'COS20240000594', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 6 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use."}
# {'name': 'NGUYEN, TAM THI', 'city': 'KILLEEN', 'county': '76542', 'zip_code': 'COS20240008070', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to utilize clean and disinfected implements; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, DUNG THANH', 'city': 'FRIENDSWOOD', 'county': '77546', 'zip_code': 'COS20240001947', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client.'}
# {'name': 'NGUYEN, AJ', 'city': 'AUSTIN', 'county': '78739', 'zip_code': 'COS20230009966', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent engaged in gross malpractice.'}
# {'name': 'NGUYEN, LAM THE', 'city': 'DALLAS', 'county': '75254', 'zip_code': 'COS20220016043', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly, the Department is charging 4 violations.'}
# {'name': 'NGUYEN, QUY KIM', 'city': 'GATESVILLE', 'county': '76528', 'zip_code': 'COS20230015854', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent offered to perform barbering services outside the scope of the Establishment's license; Respondent failed to cooperate with the inspector or investigator in the performance of an inspection or investigation; Respondent failed to dispose of after each use all products and single use items that had been in contact with a client's skin."}
# {'name': 'NGUYEN, THI THIBICH', 'city': 'CORPUS CHRISTI', 'county': '78415', 'zip_code': 'COS20220002410', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}
# {'name': 'NGUYEN, TONY MINH', 'city': 'MARBLE FALLS', 'county': '78654', 'zip_code': 'COS20230002569', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.'}
# {'name': 'NGUYEN, JIMMY', 'city': 'SAN ANTONIO', 'county': '78251', 'zip_code': 'COS20230013709', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondents operated a cosmetology salon without the appropriate license.'}
# {'name': 'NGUYEN, CECILIA L', 'city': 'FORT WORTH', 'county': '76244', 'zip_code': 'COS20230020593', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent was in possession of bottles containing methyl methacrylate monomer.'}
# {'name': 'NGUYEN, JENNIFER HUE', 'city': 'SPRING', 'county': '77380', 'zip_code': 'SPRING', 'license_numbers': '77380', 'complaint_no': 'COS20240005064', 'complaint': 'Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'}
# {'name': 'NGUYEN, ANH DUC PHONG', 'city': 'BROWNSVILLE', 'county': '78521', 'zip_code': 'COS20230018810', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent employed an individual as an operator who had not obtained a cosmetology license.'}
# {'name': 'NGUYEN, HUNG', 'city': 'AUSTIN', 'county': '78758', 'zip_code': 'MAS20230000290', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent allowed an individual, including a student, license holder, or employee, to reside on the premises of the massage establishment.'}
# {'name': 'NGUYEN, THAO THANH', 'city': 'TOMBALL', 'county': '77375', 'zip_code': 'COS20230000401', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondent reused wax; Respondent stored chemicals in a restroom accessible to the public; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations.'}
# {'name': 'NGUYEN, JOHN T', 'city': 'AMARILLO', 'county': '79106', 'zip_code': 'COS20220009661', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, THUY THU THI', 'city': 'DENISON', 'county': '75020', 'zip_code': 'COS20230013043', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 3 violations; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# {'name': 'NGUYEN, STEVEN T', 'city': 'CORPUS CHRISTI', 'county': '78414', 'zip_code': 'COS20230001042', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use.'}
# {'name': 'NGUYEN, DANIEL THAO', 'city': 'PLANO', 'county': '75093', 'zip_code': 'COS20230002419', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.'}
# {'name': 'NGUYEN, THI THUY', 'city': 'WICHITA FALLS', 'county': '76310', 'zip_code': 'COS20240002426', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."}
# {'name': 'NGUYEN, JOHN', 'city': 'BELTON', 'county': '76513', 'zip_code': 'COS20220015806', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and disinfect all wax pots; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations.'}
# {'name': 'NGUYEN, STEVEN QUOC', 'city': 'SAN ANGELO', 'county': '76904', 'zip_code': 'COS20230007454', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent employed an individual as an operator who had not obtained a cosmetology license.'}
# {'name': 'NGUYEN, THU THI', 'city': 'HOUSTON', 'county': '77031', 'zip_code': 'COS20230009980', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondents failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondents failed to discard single use implements after each use; Respondents failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, TUONG', 'city': 'FORT WORTH', 'county': '76120', 'zip_code': 'COS20230001960', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondents employed an individual as an operator who had not obtained a cosmetology license; Respondents failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondents failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondents failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondents failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use; Respondents failed to keep all products properly labeled in compliance with OSHA requirements."}
# {'name': 'NGUYEN, HUONG T', 'city': 'SAN ANTONIO', 'county': '78259', 'zip_code': 'COS20220017901', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and disinfect facial chairs and beds, including headrest, prior to providing service to each client, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# {'name': 'NGUYEN, STEVEN QUOC', 'city': 'SAN ANGELO', 'county': '76904', 'zip_code': 'COS20220018135', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent employed an individual as an operator who had not obtained a cosmetology license, the Department is charging 3 violations.'}
# {'name': 'NGUYEN, HUONG THI NGOC', 'city': 'MANSFIELD', 'county': '76063', 'zip_code': 'COS20220016107', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 2 violations.'}
# {'name': 'NGUYEN, TAMMY', 'city': 'TOMBALL', 'county': '77375', 'zip_code': 'TOMBALL', 'license_numbers': '77375', 'complaint_no': 'COS20220013443', 'complaint': 'Respondents employed an unlicensed individual to perform cosmetology services.'}
# {'name': 'NGUYEN, TOAN DUC', 'city': 'SUGAR LAND', 'county': '77478', 'zip_code': 'COS20220015714', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, NHAN TRONG', 'city': 'SAN ANTONIO', 'county': '78247', 'zip_code': 'COS20220012646', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required;  Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily, bi-weekly, and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, TAM PHUONG', 'city': 'SAN ANTONIO', 'county': '78259', 'zip_code': 'COS20220012645', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required daily and before use by each patron; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, NHUNG NGOC THI', 'city': 'ALLEN', 'county': '75002', 'zip_code': 'COS20230010084', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license; Respondent failed to cooperate with the inspector in the performance of an inspection.'}
# {'name': 'NGUYEN, ANH NGOC', 'city': 'HUFFMAN', 'county': '77336', 'zip_code': 'HOUSTON', 'license_numbers': '77026', 'complaint_no': 'COS20230010404', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, HUYEN THI', 'city': 'ARLINGTON', 'county': '76010', 'zip_code': 'COS20220015853', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'}
# {'name': 'NGUYEN, DANIEL', 'city': 'BRYAN', 'county': '77807', 'zip_code': 'COS20220008852', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to dispose of after each use all products and single use items that had been in contact with a client's skin."}
# {'name': 'NGUYEN, BANG', 'city': 'HOUSTON', 'county': '77095', 'zip_code': 'COS20230009558', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 3 violations; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations.'}
# {'name': 'NGUYEN, HONG N', 'city': 'HOUSTON', 'county': '77064', 'zip_code': 'HOUSTON', 'license_numbers': '77246', 'complaint_no': 'COS20230010492', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is chrging 2 violations."}
# {'name': 'NGUYEN, TUYET', 'city': 'GRAND PRAIRIE', 'county': '75052', 'zip_code': 'COS20230000043', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, TUYET MINH', 'city': 'DALLAS', 'county': '75249', 'zip_code': 'COS20220006122', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry; Respondent failed to store in a clean, dry, debris-free environment, separate from soiled implements and materials, all cleaned and disinfected implements and materials when not in use.'}
# {'name': 'NGUYEN, JOHN THANH NHAN', 'city': 'SAN ANTONIO', 'county': '78240', 'zip_code': 'COS20220009835', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, THE THI', 'city': 'LEVELLAND', 'county': '79336', 'zip_code': 'COS20210007272', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair."}
# {'name': 'NGUYEN, THAO HONG', 'city': 'SAN ANTONIO', 'county': '78259', 'zip_code': 'COS20210012244', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent employed a person as an operator who had not obtained a cosmetology license; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.'}
# {'name': 'NGUYEN, NGOC THI', 'city': 'HOUSTON', 'county': '77072', 'zip_code': 'COS20210016437', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 2 violations; Respondent failed to dispose of single use items after each use; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to keep floors, walls, ceilings, shelves, furniture, furnishings, and fixtures clean and in good repair, the Department is charging 2 violations.'}
# {'name': 'NGUYEN, TUYEN THANH', 'city': 'AUBREY', 'county': '76227', 'zip_code': 'COS20220007001', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent used salon as a living, dining, or sleeping quarters; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 6 violations; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day, the Department is charging 6 violations; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent was in possession of bottles containing methyl methacrylate monomer; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product."}
# {'name': 'NGUYEN, MINH THU', 'city': 'EL PASO', 'county': '79934', 'zip_code': 'COS20220009623', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, LOAN THI NGOC', 'city': 'CENTER', 'county': '75935', 'zip_code': 'COS20220014041', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to wash towels in hot water and chlorine bleach, the Department is charging 4 violations; Respondent failed to dispose of single use items after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# {'name': 'NGUYEN, JACK', 'city': 'CREEDMOOR', 'county': '78610', 'zip_code': 'COS20220016162', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 4 violations; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and disinfect manicure tables prior to use for each client.'}
# {'name': 'NGUYEN, HOANG DRAGON', 'city': 'FORT WORTH', 'county': '76131', 'zip_code': 'COS20210009264', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}
# {'name': 'NGUYEN, KELLY', 'city': 'SCHERTZ', 'county': '78154', 'zip_code': 'COS20210012950', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to use items subject to possible cross contamination in a manner that does not contaminate the remaining product.'}
# {'name': 'NGUYEN, NIEN', 'city': 'FORT WORTH', 'county': '76244', 'zip_code': 'COS20210013902', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent stored chemicals in a restroom accessible to the public; Respondent failed to clean and disinfect all wax pots; Respondent failed to store cosmetology items separate from non-cosmetology items; Respondent failed to keep all products properly labeled in compliance with OSHA requirements; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, AJ', 'city': 'AUSTIN', 'county': '78739', 'zip_code': 'COS20220005426', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 11 violations; Respondent failed to prepare fresh disinfectant solution daily or more often as needed, for immersion of implements."}
# {'name': 'NGUYEN, CHARLIE', 'city': 'DALLAS', 'county': '75219', 'zip_code': 'MAS20210010410', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent operated a massage establishment without a massage establishment license; Respondent employed an unlicensed individual to perform massage therapy services.'}
# {'name': 'NGUYEN, OANH THI THUY', 'city': 'ANGLETON', 'county': '77515', 'zip_code': 'COS20210012469', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent reused wax.'}
# {'name': 'NGUYEN, LOC', 'city': 'ARLINGTON', 'county': '76018', 'zip_code': 'COS20220004591', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required, the Department is charging 5 violations; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 5 violations; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions; Respondent failed to clean and disinfect all wax pots; Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use, the Department is charging 8 violations."}
# {'name': 'NGUYEN, THAI VAN', 'city': 'GARLAND', 'county': '75040', 'zip_code': 'COS20220005795', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to cooperate with the inspector in the performance of an inspection; Respondent leased space in a salon to an individual who engaged in the practice of cosmetology but had not obtained a cosmetology license.'}
# {'name': 'NGUYEN, THUY THU THI', 'city': 'DENISON', 'county': '75020', 'zip_code': 'COS20230000013', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used; Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, DUC VAN', 'city': 'MCALLEN', 'county': '78504', 'zip_code': 'COS20220000293', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to disinfect tools, implements, and supplies with an EPA-registered disinfectant solution; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 2 violations; Respondent failed to keep all products properly labeled in compliance with OSHA requirements.'}
# {'name': 'NGUYEN, HUNG THANH', 'city': 'MISSOURI CITY', 'county': '77459', 'zip_code': 'COS20210012920', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent stored chemicals in a restroom accessible to the public; Respondent failed to disinfect diamond, carbide, natural and metal bits by complete immersion in an appropriate disinfectant; Respondent reused wax.'}
# {'name': 'NGUYEN, MIKE NHAN', 'city': 'ARLINGTON', 'county': '76017', 'zip_code': 'COS20220006428', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, SAMANTHA T', 'city': 'LITTLE ELM', 'county': '75068', 'zip_code': 'COS20220011063', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to clean, disinfect, and sterilize metal instruments with a Department-approved sterilizer in accordance with the sterilizer or sanitizers manufacturer's instructions."}
# {'name': 'NGUYEN, THOMAS', 'city': 'HOUSTON', 'county': '77042', 'zip_code': 'MAS20210004328', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondents operated a massage establishment without a massage establishment license, the Department is charging 3 violations; Respondents allowed an employee to engage in sexual contact in the massage establishment, the Department is charging 3 violations; Respondents allowed an individual, including a student, license holder, or employee, to reside on the premises of the massage establishment, the Department is charging 2 violations; Respondents employed an unlicensed individual to perform massage therapy services, the Department is charging 5 violations; Respondents' representative failed to cooperate with the investigator in the performance of the inspection; Respondents failed to properly maintain and secure for each client the initial consultation documents, all session notes, and related billing records."}
# {'name': 'NGUYEN, HIEU VAN', 'city': 'EDINBURG', 'county': '78542', 'zip_code': 'COS20230002643', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent's license was revoked upon Respondent's imprisonment in a penitentiary."}
# {'name': 'NGUYEN, MYTU THI', 'city': 'SAN ANTONIO', 'county': '78254', 'zip_code': 'COS20220012452', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': "Respondent failed to disinfect the salon's whirlpool foot spa basins with an EPA-registered disinfectant after each client, the Department is charging 2 violations."}
# {'name': 'NGUYEN, NGOC', 'city': 'MINEOLA', 'county': '75773', 'zip_code': 'COS20220009944', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to dispose of single use items after each use; Respondent possessed an electric drill other than those specifically designed and manufactured for use in the professional nail industry.'}
# {'name': 'NGUYEN, BINH PHUONG THI', 'city': 'FAIR OAKS RANCH', 'county': '78015', 'zip_code': 'COS20210014192', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, QUI NGOC', 'city': 'FLINT', 'county': '75762', 'zip_code': 'COS20220016639', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent has been convicted of an offense which makes them unfit to hold a license.'}
# {'name': 'NGUYEN, TRINH', 'city': 'UHLAND', 'county': '78640', 'zip_code': 'SPA20220009295', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent falsified records, the Department is charging 5 violations.'}
# {'name': 'NGUYEN, MUOI', 'city': 'SAN ANTONIO', 'county': '78233', 'zip_code': 'COS20210013960', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean, disinfect, and sterilize manicure and pedicure implements after each use; Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required.'}
# {'name': 'NGUYEN, CHARLIE', 'city': 'DALLAS', 'county': '75219', 'zip_code': 'COS20210015021', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, TONY VAN', 'city': 'SAN ANTONIO', 'county': '78247', 'zip_code': 'COS20210015551', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day.'}
# {'name': 'NGUYEN, NGOC THAO DANG', 'city': 'LUBBOCK', 'county': '79424', 'zip_code': 'COS20210016400', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day;  Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required bi-weekly.'}
# {'name': 'NGUYEN, KELLY PHUONG N', 'city': 'GARDEN GROVE', 'county': '92843', 'zip_code': 'COS20220006797', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used, the Department is charging 3 violations; Respondent failed to utilize clean and disinfected implements; Respondent failed to dispose of single use items after each use; Respondent failed to clean and disinfect cosmetology implements after use.'}
# {'name': 'NGUYEN, QUOC BAO', 'city': 'ARLINGTON', 'county': '76018', 'zip_code': 'COS20210009267', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to follow whirlpool foot spas cleaning and sanitization procedures as required; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, DANIEL THAO', 'city': 'PLANO', 'county': '75093', 'zip_code': 'COS20220004501', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, THANH THU', 'city': 'EL PASO', 'county': '79904', 'zip_code': 'COS20210012742', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to clean and sanitize whirlpool foot spas as required at the end of each day; Respondent failed to keep a record of the date and time of each foot spa daily or bi-weekly cleaning and if the foot spa was not used.'}
# {'name': 'NGUYEN, CINDY', 'city': 'TEMPLE', 'county': '76504', 'zip_code': 'COS20220004954', 'license_numbers': 'No license numbers', 'complaint_no': 'No complaint number', 'complaint': 'Respondent failed to utilize clean and disinfected implements.'}

# %% [markdown]
# ### Save that to a CSV named `output.csv`
#
# The dataframe should look something like...
#
# |index|name|city|county|zip_code|complaint_no|license_numbers|complaint|
# |---|---|---|---|---|---|---|---|
# |0|NGUYEN, THANH|FRISCO|COLLIN|75034|COS20210004784|790672|Respondent failed to clean and sanitize whirlp...|
# |1|NGUYEN, LONG D|SAN SABA|SAN SABA|76877|COS20210009745|760420, 1620583|Respondent failed to keep a record of the date...|
#
#
# - *Tip: If you send a list of dictionaries to `pd.DataFrame(...)`, it will create a dataframe out of that list!*

# %%
import pandas as pd

# %%
df = pd.DataFrame(results)
output_file = 'texas_output.csv'
df.to_csv(output_file, index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few. Make sure you didn't save an extra weird unnamed column.

# %%
pd.read_csv('texas_output.csv')
# Out:
#                       name          city  county        zip_code  \
# 0       NGUYEN, ELLIE UYEN        HUMBLE   77346  COS20240003068
# 1             NGUYEN, PHUC       HOUSTON   77083  COS20230005653
# 2            NGUYEN, TRONG    FORT WORTH   76177  COS20240011518
# 3               NGUYEN, SA        AUSTIN   78729  COS20240008640
# 4             NGUYEN, LYNH    RICHARDSON   75081  COS20230004635
# ..                     ...           ...     ...             ...
# 78  NGUYEN, KELLY PHUONG N  GARDEN GROVE   92843  COS20220006797
# 79        NGUYEN, QUOC BAO     ARLINGTON   76018  COS20210009267
# 80     NGUYEN, DANIEL THAO         PLANO   75093  COS20220004501
# 81       NGUYEN, THANH THU       EL PASO   79904  COS20210012742
# 82           NGUYEN, CINDY        TEMPLE   76504  COS20220004954
#
#        license_numbers         complaint_no  \
# 0   No license numbers  No complaint number
# 1   No license numbers  No complaint number
# 2   No license numbers  No complaint number
# 3   No license numbers  No complaint number
# 4   No license numbers  No complaint number
# ..                 ...                  ...
# 78  No license numbers  No complaint number
# 79  No license numbers  No complaint number
# 80  No license numbers  No complaint number
# 81  No license numbers  No complaint number
# 82  No license numbers  No complaint number
#
#                                             complaint
# 0   Respondents failed to clean, disinfect, and st...
# 1   Respondent failed to follow whirlpool foot spa...
# 2   Respondents failed to follow whirlpool foot sp...
# 3   Respondent failed to follow whirlpool foot spa...
# 4   Respondent failed to follow whirlpool foot spa...
# ..                                                ...
# 78  Respondent failed to keep a record of the date...
# 79  Respondent failed to follow whirlpool foot spa...
# 80  Respondent failed to clean and sanitize whirlp...
# 81  Respondent failed to clean and sanitize whirlp...
# 82  Respondent failed to utilize clean and disinfe...
#
# [83 rows x 7 columns]
